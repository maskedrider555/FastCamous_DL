# %% [markdown]
# # 1. Darknet Clone
#
# Runtime => GPU

# %%
# clone darkenet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15420, done.
# remote: Total 15420 (delta 0), reused 0 (delta 0), pack-reused 15420
# Receiving objects: 100% (15420/15420), 14.05 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (10360/10360), done.

# %%
# !ls -al darknet
# Out:
# total 268
# drwxr-xr-x 14 root root  4096 Jun  1 08:11 .
# drwxr-xr-x  1 root root  4096 Jun  1 08:11 ..
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 3rdparty
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 build
# -rwxr-xr-x  1 root root 32896 Jun  1 08:11 build.ps1
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 cfg
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 .circleci
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 cmake
# -rw-r--r--  1 root root 25373 Jun  1 08:11 CMakeLists.txt
# -rw-r--r--  1 root root  1479 Jun  1 08:11 DarknetConfig.cmake.in
# -rw-r--r--  1 root root  9541 Jun  1 08:11 darknet_images.py
# -rw-r--r--  1 root root 10828 Jun  1 08:11 darknet.py
# -rw-r--r--  1 root root  6747 Jun  1 08:11 darknet_video.py
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 data
# drwxr-xr-x  8 root root  4096 Jun  1 08:11 .git
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 .github
# -rw-r--r--  1 root root   686 Jun  1 08:11 .gitignore
# -rwxr-xr-x  1 root root   110 Jun  1 08:11 image_yolov3.sh
# -rwxr-xr-x  1 root root   110 Jun  1 08:11 image_yolov4.sh
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 include
# -rwxr-xr-x  1 root root   345 Jun  1 08:11 json_mjpeg_streams.sh
# -rw-r--r--  1 root root   515 Jun  1 08:11 LICENSE
# -rw-r--r--  1 root root  5961 Jun  1 08:11 Makefile
# -rwxr-xr-x  1 root root   159 Jun  1 08:11 net_cam_v3.sh
# -rwxr-xr-x  1 root root   159 Jun  1 08:11 net_cam_v4.sh
# -rw-r--r--  1 root root 65282 Jun  1 08:11 README.md
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 results
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 scripts
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 src
# -rw-r--r--  1 root root  2609 Jun  1 08:11 vcpkg.json
# -rwxr-xr-x  1 root root   108 Jun  1 08:11 video_yolov3.sh
# -rwxr-xr-x  1 root root   108 Jun  1 08:11 video_yolov4.sh

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !ls -al
# Out:
# total 268
# drwxr-xr-x 14 root root  4096 Jun  1 08:11 .
# drwxr-xr-x  1 root root  4096 Jun  1 08:11 ..
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 3rdparty
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 build
# -rwxr-xr-x  1 root root 32896 Jun  1 08:11 build.ps1
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 cfg
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 .circleci
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 cmake
# -rw-r--r--  1 root root 25373 Jun  1 08:11 CMakeLists.txt
# -rw-r--r--  1 root root  1479 Jun  1 08:11 DarknetConfig.cmake.in
# -rw-r--r--  1 root root  9541 Jun  1 08:11 darknet_images.py
# -rw-r--r--  1 root root 10828 Jun  1 08:11 darknet.py
# -rw-r--r--  1 root root  6747 Jun  1 08:11 darknet_video.py
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 data
# drwxr-xr-x  8 root root  4096 Jun  1 08:11 .git
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 .github
# -rw-r--r--  1 root root   686 Jun  1 08:11 .gitignore
# -rwxr-xr-x  1 root root   110 Jun  1 08:11 image_yolov3.sh
# -rwxr-xr-x  1 root root   110 Jun  1 08:11 image_yolov4.sh
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 include
# -rwxr-xr-x  1 root root   345 Jun  1 08:11 json_mjpeg_streams.sh
# -rw-r--r--  1 root root   515 Jun  1 08:11 LICENSE
# -rw-r--r--  1 root root  5961 Jun  1 08:11 Makefile
# -rwxr-xr-x  1 root root   159 Jun  1 08:11 net_cam_v3.sh
# -rwxr-xr-x  1 root root   159 Jun  1 08:11 net_cam_v4.sh
# -rw-r--r--  1 root root 65282 Jun  1 08:11 README.md
# drwxr-xr-x  2 root root  4096 Jun  1 08:11 results
# drwxr-xr-x  4 root root  4096 Jun  1 08:11 scripts
# drwxr-xr-x  3 root root  4096 Jun  1 08:11 src
# -rw-r--r--  1 root root  2609 Jun  1 08:11 vcpkg.json
# -rwxr-xr-x  1 root root   108 Jun  1 08:11 video_yolov3.sh
# -rwxr-xr-x  1 root root   108 Jun  1 08:11 video_yolov4.sh

# %%
# !ls -al data
# Out:
# total 1744
# drwxr-xr-x  3 root root   4096 Jun  1 08:11 .
# drwxr-xr-x 14 root root   4096 Jun  1 08:11 ..
# -rw-r--r--  1 root root 140047 Jun  1 08:11 9k.tree
# -rw-r--r--  1 root root    387 Jun  1 08:11 coco9k.map
# -rw-r--r--  1 root root    625 Jun  1 08:11 coco.names
# -rw-r--r--  1 root root 163759 Jun  1 08:11 dog.jpg
# -rw-r--r--  1 root root 141886 Jun  1 08:11 eagle.jpg
# -rw-r--r--  1 root root 382965 Jun  1 08:11 giraffe.jpg
# -rw-r--r--  1 root root     80 Jun  1 08:11 goal.txt
# -rw-r--r--  1 root root 133495 Jun  1 08:11 horses.jpg
# -rw-r--r--  1 root root 218420 Jun  1 08:11 imagenet.labels.list
# -rw-r--r--  1 root root 246356 Jun  1 08:11 imagenet.shortnames.list
# drwxr-xr-x  2 root root  20480 Jun  1 08:11 labels
# -rw-r--r--  1 root root   5476 Jun  1 08:11 openimages.names
# -rw-r--r--  1 root root 113880 Jun  1 08:11 person.jpg
# -rw-r--r--  1 root root 174515 Jun  1 08:11 scream.jpg
# -rw-r--r--  1 root root    135 Jun  1 08:11 voc.names

# %%
# !ls -al data/labels
# Out:
# total 3068
# drwxr-xr-x 2 root root 20480 Jun  1 08:11 .
# drwxr-xr-x 3 root root  4096 Jun  1 08:11 ..
# -rw-r--r-- 1 root root   320 Jun  1 08:11 100_0.png
# -rw-r--r-- 1 root root   377 Jun  1 08:11 100_1.png
# -rw-r--r-- 1 root root   451 Jun  1 08:11 100_2.png
# -rw-r--r-- 1 root root   508 Jun  1 08:11 100_3.png
# -rw-r--r-- 1 root root   577 Jun  1 08:11 100_4.png
# -rw-r--r-- 1 root root   631 Jun  1 08:11 100_5.png
# -rw-r--r-- 1 root root   697 Jun  1 08:11 100_6.png
# -rw-r--r-- 1 root root   753 Jun  1 08:11 100_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 101_0.png
# -rw-r--r-- 1 root root   388 Jun  1 08:11 101_1.png
# -rw-r--r-- 1 root root   458 Jun  1 08:11 101_2.png
# -rw-r--r-- 1 root root   514 Jun  1 08:11 101_3.png
# -rw-r--r-- 1 root root   581 Jun  1 08:11 101_4.png
# -rw-r--r-- 1 root root   654 Jun  1 08:11 101_5.png
# -rw-r--r-- 1 root root   726 Jun  1 08:11 101_6.png
# -rw-r--r-- 1 root root   804 Jun  1 08:11 101_7.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 102_0.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 102_1.png
# -rw-r--r-- 1 root root   354 Jun  1 08:11 102_2.png
# -rw-r--r-- 1 root root   371 Jun  1 08:11 102_3.png
# -rw-r--r-- 1 root root   398 Jun  1 08:11 102_4.png
# -rw-r--r-- 1 root root   411 Jun  1 08:11 102_5.png
# -rw-r--r-- 1 root root   422 Jun  1 08:11 102_6.png
# -rw-r--r-- 1 root root   442 Jun  1 08:11 102_7.png
# -rw-r--r-- 1 root root   333 Jun  1 08:11 103_0.png
# -rw-r--r-- 1 root root   415 Jun  1 08:11 103_1.png
# -rw-r--r-- 1 root root   521 Jun  1 08:11 103_2.png
# -rw-r--r-- 1 root root   586 Jun  1 08:11 103_3.png
# -rw-r--r-- 1 root root   687 Jun  1 08:11 103_4.png
# -rw-r--r-- 1 root root   781 Jun  1 08:11 103_5.png
# -rw-r--r-- 1 root root   858 Jun  1 08:11 103_6.png
# -rw-r--r-- 1 root root   971 Jun  1 08:11 103_7.png
# -rw-r--r-- 1 root root   315 Jun  1 08:11 104_0.png
# -rw-r--r-- 1 root root   345 Jun  1 08:11 104_1.png
# -rw-r--r-- 1 root root   382 Jun  1 08:11 104_2.png
# -rw-r--r-- 1 root root   412 Jun  1 08:11 104_3.png
# -rw-r--r-- 1 root root   439 Jun  1 08:11 104_4.png
# -rw-r--r-- 1 root root   476 Jun  1 08:11 104_5.png
# -rw-r--r-- 1 root root   511 Jun  1 08:11 104_6.png
# -rw-r--r-- 1 root root   542 Jun  1 08:11 104_7.png
# -rw-r--r-- 1 root root   296 Jun  1 08:11 105_0.png
# -rw-r--r-- 1 root root   306 Jun  1 08:11 105_1.png
# -rw-r--r-- 1 root root   318 Jun  1 08:11 105_2.png
# -rw-r--r-- 1 root root   336 Jun  1 08:11 105_3.png
# -rw-r--r-- 1 root root   352 Jun  1 08:11 105_4.png
# -rw-r--r-- 1 root root   360 Jun  1 08:11 105_5.png
# -rw-r--r-- 1 root root   379 Jun  1 08:11 105_6.png
# -rw-r--r-- 1 root root   391 Jun  1 08:11 105_7.png
# -rw-r--r-- 1 root root   293 Jun  1 08:11 106_0.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 106_1.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 106_2.png
# -rw-r--r-- 1 root root   335 Jun  1 08:11 106_3.png
# -rw-r--r-- 1 root root   348 Jun  1 08:11 106_4.png
# -rw-r--r-- 1 root root   363 Jun  1 08:11 106_5.png
# -rw-r--r-- 1 root root   374 Jun  1 08:11 106_6.png
# -rw-r--r-- 1 root root   390 Jun  1 08:11 106_7.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 107_0.png
# -rw-r--r-- 1 root root   358 Jun  1 08:11 107_1.png
# -rw-r--r-- 1 root root   410 Jun  1 08:11 107_2.png
# -rw-r--r-- 1 root root   446 Jun  1 08:11 107_3.png
# -rw-r--r-- 1 root root   490 Jun  1 08:11 107_4.png
# -rw-r--r-- 1 root root   526 Jun  1 08:11 107_5.png
# -rw-r--r-- 1 root root   581 Jun  1 08:11 107_6.png
# -rw-r--r-- 1 root root   609 Jun  1 08:11 107_7.png
# -rw-r--r-- 1 root root   285 Jun  1 08:11 108_0.png
# -rw-r--r-- 1 root root   288 Jun  1 08:11 108_1.png
# -rw-r--r-- 1 root root   296 Jun  1 08:11 108_2.png
# -rw-r--r-- 1 root root   298 Jun  1 08:11 108_3.png
# -rw-r--r-- 1 root root   298 Jun  1 08:11 108_4.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 108_5.png
# -rw-r--r-- 1 root root   302 Jun  1 08:11 108_6.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 108_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 109_0.png
# -rw-r--r-- 1 root root   371 Jun  1 08:11 109_1.png
# -rw-r--r-- 1 root root   426 Jun  1 08:11 109_2.png
# -rw-r--r-- 1 root root   475 Jun  1 08:11 109_3.png
# -rw-r--r-- 1 root root   528 Jun  1 08:11 109_4.png
# -rw-r--r-- 1 root root   587 Jun  1 08:11 109_5.png
# -rw-r--r-- 1 root root   628 Jun  1 08:11 109_6.png
# -rw-r--r-- 1 root root   694 Jun  1 08:11 109_7.png
# -rw-r--r-- 1 root root   312 Jun  1 08:11 110_0.png
# -rw-r--r-- 1 root root   341 Jun  1 08:11 110_1.png
# -rw-r--r-- 1 root root   378 Jun  1 08:11 110_2.png
# -rw-r--r-- 1 root root   414 Jun  1 08:11 110_3.png
# -rw-r--r-- 1 root root   444 Jun  1 08:11 110_4.png
# -rw-r--r-- 1 root root   479 Jun  1 08:11 110_5.png
# -rw-r--r-- 1 root root   509 Jun  1 08:11 110_6.png
# -rw-r--r-- 1 root root   544 Jun  1 08:11 110_7.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 111_0.png
# -rw-r--r-- 1 root root   396 Jun  1 08:11 111_1.png
# -rw-r--r-- 1 root root   471 Jun  1 08:11 111_2.png
# -rw-r--r-- 1 root root   534 Jun  1 08:11 111_3.png
# -rw-r--r-- 1 root root   615 Jun  1 08:11 111_4.png
# -rw-r--r-- 1 root root   686 Jun  1 08:11 111_5.png
# -rw-r--r-- 1 root root   781 Jun  1 08:11 111_6.png
# -rw-r--r-- 1 root root   855 Jun  1 08:11 111_7.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 112_0.png
# -rw-r--r-- 1 root root   382 Jun  1 08:11 112_1.png
# -rw-r--r-- 1 root root   450 Jun  1 08:11 112_2.png
# -rw-r--r-- 1 root root   507 Jun  1 08:11 112_3.png
# -rw-r--r-- 1 root root   568 Jun  1 08:11 112_4.png
# -rw-r--r-- 1 root root   641 Jun  1 08:11 112_5.png
# -rw-r--r-- 1 root root   710 Jun  1 08:11 112_6.png
# -rw-r--r-- 1 root root   766 Jun  1 08:11 112_7.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 113_0.png
# -rw-r--r-- 1 root root   386 Jun  1 08:11 113_1.png
# -rw-r--r-- 1 root root   450 Jun  1 08:11 113_2.png
# -rw-r--r-- 1 root root   506 Jun  1 08:11 113_3.png
# -rw-r--r-- 1 root root   572 Jun  1 08:11 113_4.png
# -rw-r--r-- 1 root root   631 Jun  1 08:11 113_5.png
# -rw-r--r-- 1 root root   702 Jun  1 08:11 113_6.png
# -rw-r--r-- 1 root root   760 Jun  1 08:11 113_7.png
# -rw-r--r-- 1 root root   299 Jun  1 08:11 114_0.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 114_1.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 114_2.png
# -rw-r--r-- 1 root root   363 Jun  1 08:11 114_3.png
# -rw-r--r-- 1 root root   391 Jun  1 08:11 114_4.png
# -rw-r--r-- 1 root root   413 Jun  1 08:11 114_5.png
# -rw-r--r-- 1 root root   441 Jun  1 08:11 114_6.png
# -rw-r--r-- 1 root root   460 Jun  1 08:11 114_7.png
# -rw-r--r-- 1 root root   315 Jun  1 08:11 115_0.png
# -rw-r--r-- 1 root root   373 Jun  1 08:11 115_1.png
# -rw-r--r-- 1 root root   436 Jun  1 08:11 115_2.png
# -rw-r--r-- 1 root root   497 Jun  1 08:11 115_3.png
# -rw-r--r-- 1 root root   552 Jun  1 08:11 115_4.png
# -rw-r--r-- 1 root root   618 Jun  1 08:11 115_5.png
# -rw-r--r-- 1 root root   687 Jun  1 08:11 115_6.png
# -rw-r--r-- 1 root root   766 Jun  1 08:11 115_7.png
# -rw-r--r-- 1 root root   299 Jun  1 08:11 116_0.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 116_1.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 116_2.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 116_3.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 116_4.png
# -rw-r--r-- 1 root root   328 Jun  1 08:11 116_5.png
# -rw-r--r-- 1 root root   332 Jun  1 08:11 116_6.png
# -rw-r--r-- 1 root root   337 Jun  1 08:11 116_7.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 117_0.png
# -rw-r--r-- 1 root root   350 Jun  1 08:11 117_1.png
# -rw-r--r-- 1 root root   386 Jun  1 08:11 117_2.png
# -rw-r--r-- 1 root root   421 Jun  1 08:11 117_3.png
# -rw-r--r-- 1 root root   470 Jun  1 08:11 117_4.png
# -rw-r--r-- 1 root root   515 Jun  1 08:11 117_5.png
# -rw-r--r-- 1 root root   549 Jun  1 08:11 117_6.png
# -rw-r--r-- 1 root root   584 Jun  1 08:11 117_7.png
# -rw-r--r-- 1 root root   315 Jun  1 08:11 118_0.png
# -rw-r--r-- 1 root root   369 Jun  1 08:11 118_1.png
# -rw-r--r-- 1 root root   442 Jun  1 08:11 118_2.png
# -rw-r--r-- 1 root root   502 Jun  1 08:11 118_3.png
# -rw-r--r-- 1 root root   576 Jun  1 08:11 118_4.png
# -rw-r--r-- 1 root root   653 Jun  1 08:11 118_5.png
# -rw-r--r-- 1 root root   682 Jun  1 08:11 118_6.png
# -rw-r--r-- 1 root root   750 Jun  1 08:11 118_7.png
# -rw-r--r-- 1 root root   334 Jun  1 08:11 119_0.png
# -rw-r--r-- 1 root root   432 Jun  1 08:11 119_1.png
# -rw-r--r-- 1 root root   550 Jun  1 08:11 119_2.png
# -rw-r--r-- 1 root root   657 Jun  1 08:11 119_3.png
# -rw-r--r-- 1 root root   759 Jun  1 08:11 119_4.png
# -rw-r--r-- 1 root root   886 Jun  1 08:11 119_5.png
# -rw-r--r-- 1 root root   977 Jun  1 08:11 119_6.png
# -rw-r--r-- 1 root root  1086 Jun  1 08:11 119_7.png
# -rw-r--r-- 1 root root   316 Jun  1 08:11 120_0.png
# -rw-r--r-- 1 root root   380 Jun  1 08:11 120_1.png
# -rw-r--r-- 1 root root   452 Jun  1 08:11 120_2.png
# -rw-r--r-- 1 root root   509 Jun  1 08:11 120_3.png
# -rw-r--r-- 1 root root   580 Jun  1 08:11 120_4.png
# -rw-r--r-- 1 root root   634 Jun  1 08:11 120_5.png
# -rw-r--r-- 1 root root   706 Jun  1 08:11 120_6.png
# -rw-r--r-- 1 root root   773 Jun  1 08:11 120_7.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 121_0.png
# -rw-r--r-- 1 root root   395 Jun  1 08:11 121_1.png
# -rw-r--r-- 1 root root   477 Jun  1 08:11 121_2.png
# -rw-r--r-- 1 root root   563 Jun  1 08:11 121_3.png
# -rw-r--r-- 1 root root   645 Jun  1 08:11 121_4.png
# -rw-r--r-- 1 root root   726 Jun  1 08:11 121_5.png
# -rw-r--r-- 1 root root   798 Jun  1 08:11 121_6.png
# -rw-r--r-- 1 root root   866 Jun  1 08:11 121_7.png
# -rw-r--r-- 1 root root   311 Jun  1 08:11 122_0.png
# -rw-r--r-- 1 root root   352 Jun  1 08:11 122_1.png
# -rw-r--r-- 1 root root   388 Jun  1 08:11 122_2.png
# -rw-r--r-- 1 root root   421 Jun  1 08:11 122_3.png
# -rw-r--r-- 1 root root   458 Jun  1 08:11 122_4.png
# -rw-r--r-- 1 root root   500 Jun  1 08:11 122_5.png
# -rw-r--r-- 1 root root   541 Jun  1 08:11 122_6.png
# -rw-r--r-- 1 root root   556 Jun  1 08:11 122_7.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 123_0.png
# -rw-r--r-- 1 root root   384 Jun  1 08:11 123_1.png
# -rw-r--r-- 1 root root   446 Jun  1 08:11 123_2.png
# -rw-r--r-- 1 root root   503 Jun  1 08:11 123_3.png
# -rw-r--r-- 1 root root   551 Jun  1 08:11 123_4.png
# -rw-r--r-- 1 root root   601 Jun  1 08:11 123_5.png
# -rw-r--r-- 1 root root   661 Jun  1 08:11 123_6.png
# -rw-r--r-- 1 root root   712 Jun  1 08:11 123_7.png
# -rw-r--r-- 1 root root   286 Jun  1 08:11 124_0.png
# -rw-r--r-- 1 root root   288 Jun  1 08:11 124_1.png
# -rw-r--r-- 1 root root   287 Jun  1 08:11 124_2.png
# -rw-r--r-- 1 root root   294 Jun  1 08:11 124_3.png
# -rw-r--r-- 1 root root   293 Jun  1 08:11 124_4.png
# -rw-r--r-- 1 root root   299 Jun  1 08:11 124_5.png
# -rw-r--r-- 1 root root   296 Jun  1 08:11 124_6.png
# -rw-r--r-- 1 root root   301 Jun  1 08:11 124_7.png
# -rw-r--r-- 1 root root   318 Jun  1 08:11 125_0.png
# -rw-r--r-- 1 root root   385 Jun  1 08:11 125_1.png
# -rw-r--r-- 1 root root   437 Jun  1 08:11 125_2.png
# -rw-r--r-- 1 root root   496 Jun  1 08:11 125_3.png
# -rw-r--r-- 1 root root   547 Jun  1 08:11 125_4.png
# -rw-r--r-- 1 root root   602 Jun  1 08:11 125_5.png
# -rw-r--r-- 1 root root   655 Jun  1 08:11 125_6.png
# -rw-r--r-- 1 root root   689 Jun  1 08:11 125_7.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 126_0.png
# -rw-r--r-- 1 root root   343 Jun  1 08:11 126_1.png
# -rw-r--r-- 1 root root   368 Jun  1 08:11 126_2.png
# -rw-r--r-- 1 root root   406 Jun  1 08:11 126_3.png
# -rw-r--r-- 1 root root   437 Jun  1 08:11 126_4.png
# -rw-r--r-- 1 root root   483 Jun  1 08:11 126_5.png
# -rw-r--r-- 1 root root   524 Jun  1 08:11 126_6.png
# -rw-r--r-- 1 root root   561 Jun  1 08:11 126_7.png
# -rw-r--r-- 1 root root   280 Jun  1 08:11 32_0.png
# -rw-r--r-- 1 root root   281 Jun  1 08:11 32_1.png
# -rw-r--r-- 1 root root   281 Jun  1 08:11 32_2.png
# -rw-r--r-- 1 root root   282 Jun  1 08:11 32_3.png
# -rw-r--r-- 1 root root   282 Jun  1 08:11 32_4.png
# -rw-r--r-- 1 root root   285 Jun  1 08:11 32_5.png
# -rw-r--r-- 1 root root   285 Jun  1 08:11 32_6.png
# -rw-r--r-- 1 root root   285 Jun  1 08:11 32_7.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 33_0.png
# -rw-r--r-- 1 root root   313 Jun  1 08:11 33_1.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 33_2.png
# -rw-r--r-- 1 root root   339 Jun  1 08:11 33_3.png
# -rw-r--r-- 1 root root   348 Jun  1 08:11 33_4.png
# -rw-r--r-- 1 root root   365 Jun  1 08:11 33_5.png
# -rw-r--r-- 1 root root   382 Jun  1 08:11 33_6.png
# -rw-r--r-- 1 root root   393 Jun  1 08:11 33_7.png
# -rw-r--r-- 1 root root   295 Jun  1 08:11 34_0.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 34_1.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 34_2.png
# -rw-r--r-- 1 root root   316 Jun  1 08:11 34_3.png
# -rw-r--r-- 1 root root   318 Jun  1 08:11 34_4.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 34_5.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 34_6.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 34_7.png
# -rw-r--r-- 1 root root   338 Jun  1 08:11 35_0.png
# -rw-r--r-- 1 root root   445 Jun  1 08:11 35_1.png
# -rw-r--r-- 1 root root   535 Jun  1 08:11 35_2.png
# -rw-r--r-- 1 root root   636 Jun  1 08:11 35_3.png
# -rw-r--r-- 1 root root   739 Jun  1 08:11 35_4.png
# -rw-r--r-- 1 root root   830 Jun  1 08:11 35_5.png
# -rw-r--r-- 1 root root   905 Jun  1 08:11 35_6.png
# -rw-r--r-- 1 root root   999 Jun  1 08:11 35_7.png
# -rw-r--r-- 1 root root   344 Jun  1 08:11 36_0.png
# -rw-r--r-- 1 root root   441 Jun  1 08:11 36_1.png
# -rw-r--r-- 1 root root   517 Jun  1 08:11 36_2.png
# -rw-r--r-- 1 root root   599 Jun  1 08:11 36_3.png
# -rw-r--r-- 1 root root   687 Jun  1 08:11 36_4.png
# -rw-r--r-- 1 root root   762 Jun  1 08:11 36_5.png
# -rw-r--r-- 1 root root   871 Jun  1 08:11 36_6.png
# -rw-r--r-- 1 root root   949 Jun  1 08:11 36_7.png
# -rw-r--r-- 1 root root   351 Jun  1 08:11 37_0.png
# -rw-r--r-- 1 root root   491 Jun  1 08:11 37_1.png
# -rw-r--r-- 1 root root   658 Jun  1 08:11 37_2.png
# -rw-r--r-- 1 root root   858 Jun  1 08:11 37_3.png
# -rw-r--r-- 1 root root   998 Jun  1 08:11 37_4.png
# -rw-r--r-- 1 root root  1157 Jun  1 08:11 37_5.png
# -rw-r--r-- 1 root root  1259 Jun  1 08:11 37_6.png
# -rw-r--r-- 1 root root  1478 Jun  1 08:11 37_7.png
# -rw-r--r-- 1 root root   342 Jun  1 08:11 38_0.png
# -rw-r--r-- 1 root root   466 Jun  1 08:11 38_1.png
# -rw-r--r-- 1 root root   585 Jun  1 08:11 38_2.png
# -rw-r--r-- 1 root root   698 Jun  1 08:11 38_3.png
# -rw-r--r-- 1 root root   823 Jun  1 08:11 38_4.png
# -rw-r--r-- 1 root root   942 Jun  1 08:11 38_5.png
# -rw-r--r-- 1 root root  1053 Jun  1 08:11 38_6.png
# -rw-r--r-- 1 root root  1159 Jun  1 08:11 38_7.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 39_0.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 39_1.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 39_2.png
# -rw-r--r-- 1 root root   368 Jun  1 08:11 39_3.png
# -rw-r--r-- 1 root root   388 Jun  1 08:11 39_4.png
# -rw-r--r-- 1 root root   418 Jun  1 08:11 39_5.png
# -rw-r--r-- 1 root root   444 Jun  1 08:11 39_6.png
# -rw-r--r-- 1 root root   470 Jun  1 08:11 39_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 40_0.png
# -rw-r--r-- 1 root root   390 Jun  1 08:11 40_1.png
# -rw-r--r-- 1 root root   449 Jun  1 08:11 40_2.png
# -rw-r--r-- 1 root root   520 Jun  1 08:11 40_3.png
# -rw-r--r-- 1 root root   584 Jun  1 08:11 40_4.png
# -rw-r--r-- 1 root root   641 Jun  1 08:11 40_5.png
# -rw-r--r-- 1 root root   681 Jun  1 08:11 40_6.png
# -rw-r--r-- 1 root root   758 Jun  1 08:11 40_7.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 41_0.png
# -rw-r--r-- 1 root root   385 Jun  1 08:11 41_1.png
# -rw-r--r-- 1 root root   441 Jun  1 08:11 41_2.png
# -rw-r--r-- 1 root root   522 Jun  1 08:11 41_3.png
# -rw-r--r-- 1 root root   577 Jun  1 08:11 41_4.png
# -rw-r--r-- 1 root root   637 Jun  1 08:11 41_5.png
# -rw-r--r-- 1 root root   690 Jun  1 08:11 41_6.png
# -rw-r--r-- 1 root root   753 Jun  1 08:11 41_7.png
# -rw-r--r-- 1 root root   311 Jun  1 08:11 42_0.png
# -rw-r--r-- 1 root root   352 Jun  1 08:11 42_1.png
# -rw-r--r-- 1 root root   400 Jun  1 08:11 42_2.png
# -rw-r--r-- 1 root root   456 Jun  1 08:11 42_3.png
# -rw-r--r-- 1 root root   520 Jun  1 08:11 42_4.png
# -rw-r--r-- 1 root root   564 Jun  1 08:11 42_5.png
# -rw-r--r-- 1 root root   606 Jun  1 08:11 42_6.png
# -rw-r--r-- 1 root root   677 Jun  1 08:11 42_7.png
# -rw-r--r-- 1 root root   301 Jun  1 08:11 43_0.png
# -rw-r--r-- 1 root root   312 Jun  1 08:11 43_1.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 43_2.png
# -rw-r--r-- 1 root root   326 Jun  1 08:11 43_3.png
# -rw-r--r-- 1 root root   333 Jun  1 08:11 43_4.png
# -rw-r--r-- 1 root root   339 Jun  1 08:11 43_5.png
# -rw-r--r-- 1 root root   347 Jun  1 08:11 43_6.png
# -rw-r--r-- 1 root root   354 Jun  1 08:11 43_7.png
# -rw-r--r-- 1 root root   296 Jun  1 08:11 44_0.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 44_1.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 44_2.png
# -rw-r--r-- 1 root root   368 Jun  1 08:11 44_3.png
# -rw-r--r-- 1 root root   400 Jun  1 08:11 44_4.png
# -rw-r--r-- 1 root root   416 Jun  1 08:11 44_5.png
# -rw-r--r-- 1 root root   451 Jun  1 08:11 44_6.png
# -rw-r--r-- 1 root root   480 Jun  1 08:11 44_7.png
# -rw-r--r-- 1 root root   289 Jun  1 08:11 45_0.png
# -rw-r--r-- 1 root root   298 Jun  1 08:11 45_1.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 45_2.png
# -rw-r--r-- 1 root root   302 Jun  1 08:11 45_3.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 45_4.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 45_5.png
# -rw-r--r-- 1 root root   311 Jun  1 08:11 45_6.png
# -rw-r--r-- 1 root root   316 Jun  1 08:11 45_7.png
# -rw-r--r-- 1 root root   289 Jun  1 08:11 46_0.png
# -rw-r--r-- 1 root root   296 Jun  1 08:11 46_1.png
# -rw-r--r-- 1 root root   308 Jun  1 08:11 46_2.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 46_3.png
# -rw-r--r-- 1 root root   336 Jun  1 08:11 46_4.png
# -rw-r--r-- 1 root root   348 Jun  1 08:11 46_5.png
# -rw-r--r-- 1 root root   362 Jun  1 08:11 46_6.png
# -rw-r--r-- 1 root root   377 Jun  1 08:11 46_7.png
# -rw-r--r-- 1 root root   326 Jun  1 08:11 47_0.png
# -rw-r--r-- 1 root root   372 Jun  1 08:11 47_1.png
# -rw-r--r-- 1 root root   448 Jun  1 08:11 47_2.png
# -rw-r--r-- 1 root root   518 Jun  1 08:11 47_3.png
# -rw-r--r-- 1 root root   561 Jun  1 08:11 47_4.png
# -rw-r--r-- 1 root root   629 Jun  1 08:11 47_5.png
# -rw-r--r-- 1 root root   672 Jun  1 08:11 47_6.png
# -rw-r--r-- 1 root root   724 Jun  1 08:11 47_7.png
# -rw-r--r-- 1 root root   337 Jun  1 08:11 48_0.png
# -rw-r--r-- 1 root root   440 Jun  1 08:11 48_1.png
# -rw-r--r-- 1 root root   550 Jun  1 08:11 48_2.png
# -rw-r--r-- 1 root root   640 Jun  1 08:11 48_3.png
# -rw-r--r-- 1 root root   753 Jun  1 08:11 48_4.png
# -rw-r--r-- 1 root root   838 Jun  1 08:11 48_5.png
# -rw-r--r-- 1 root root   938 Jun  1 08:11 48_6.png
# -rw-r--r-- 1 root root  1023 Jun  1 08:11 48_7.png
# -rw-r--r-- 1 root root   297 Jun  1 08:11 49_0.png
# -rw-r--r-- 1 root root   306 Jun  1 08:11 49_1.png
# -rw-r--r-- 1 root root   313 Jun  1 08:11 49_2.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 49_3.png
# -rw-r--r-- 1 root root   331 Jun  1 08:11 49_4.png
# -rw-r--r-- 1 root root   335 Jun  1 08:11 49_5.png
# -rw-r--r-- 1 root root   349 Jun  1 08:11 49_6.png
# -rw-r--r-- 1 root root   352 Jun  1 08:11 49_7.png
# -rw-r--r-- 1 root root   334 Jun  1 08:11 50_0.png
# -rw-r--r-- 1 root root   414 Jun  1 08:11 50_1.png
# -rw-r--r-- 1 root root   477 Jun  1 08:11 50_2.png
# -rw-r--r-- 1 root root   550 Jun  1 08:11 50_3.png
# -rw-r--r-- 1 root root   615 Jun  1 08:11 50_4.png
# -rw-r--r-- 1 root root   689 Jun  1 08:11 50_5.png
# -rw-r--r-- 1 root root   744 Jun  1 08:11 50_6.png
# -rw-r--r-- 1 root root   840 Jun  1 08:11 50_7.png
# -rw-r--r-- 1 root root   336 Jun  1 08:11 51_0.png
# -rw-r--r-- 1 root root   428 Jun  1 08:11 51_1.png
# -rw-r--r-- 1 root root   510 Jun  1 08:11 51_2.png
# -rw-r--r-- 1 root root   608 Jun  1 08:11 51_3.png
# -rw-r--r-- 1 root root   693 Jun  1 08:11 51_4.png
# -rw-r--r-- 1 root root   787 Jun  1 08:11 51_5.png
# -rw-r--r-- 1 root root   872 Jun  1 08:11 51_6.png
# -rw-r--r-- 1 root root   958 Jun  1 08:11 51_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 52_0.png
# -rw-r--r-- 1 root root   368 Jun  1 08:11 52_1.png
# -rw-r--r-- 1 root root   412 Jun  1 08:11 52_2.png
# -rw-r--r-- 1 root root   455 Jun  1 08:11 52_3.png
# -rw-r--r-- 1 root root   502 Jun  1 08:11 52_4.png
# -rw-r--r-- 1 root root   547 Jun  1 08:11 52_5.png
# -rw-r--r-- 1 root root   589 Jun  1 08:11 52_6.png
# -rw-r--r-- 1 root root   633 Jun  1 08:11 52_7.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 53_0.png
# -rw-r--r-- 1 root root   415 Jun  1 08:11 53_1.png
# -rw-r--r-- 1 root root   495 Jun  1 08:11 53_2.png
# -rw-r--r-- 1 root root   577 Jun  1 08:11 53_3.png
# -rw-r--r-- 1 root root   658 Jun  1 08:11 53_4.png
# -rw-r--r-- 1 root root   742 Jun  1 08:11 53_5.png
# -rw-r--r-- 1 root root   820 Jun  1 08:11 53_6.png
# -rw-r--r-- 1 root root   891 Jun  1 08:11 53_7.png
# -rw-r--r-- 1 root root   339 Jun  1 08:11 54_0.png
# -rw-r--r-- 1 root root   434 Jun  1 08:11 54_1.png
# -rw-r--r-- 1 root root   543 Jun  1 08:11 54_2.png
# -rw-r--r-- 1 root root   633 Jun  1 08:11 54_3.png
# -rw-r--r-- 1 root root   723 Jun  1 08:11 54_4.png
# -rw-r--r-- 1 root root   818 Jun  1 08:11 54_5.png
# -rw-r--r-- 1 root root   907 Jun  1 08:11 54_6.png
# -rw-r--r-- 1 root root  1006 Jun  1 08:11 54_7.png
# -rw-r--r-- 1 root root   327 Jun  1 08:11 55_0.png
# -rw-r--r-- 1 root root   385 Jun  1 08:11 55_1.png
# -rw-r--r-- 1 root root   449 Jun  1 08:11 55_2.png
# -rw-r--r-- 1 root root   503 Jun  1 08:11 55_3.png
# -rw-r--r-- 1 root root   548 Jun  1 08:11 55_4.png
# -rw-r--r-- 1 root root   598 Jun  1 08:11 55_5.png
# -rw-r--r-- 1 root root   640 Jun  1 08:11 55_6.png
# -rw-r--r-- 1 root root   710 Jun  1 08:11 55_7.png
# -rw-r--r-- 1 root root   337 Jun  1 08:11 56_0.png
# -rw-r--r-- 1 root root   449 Jun  1 08:11 56_1.png
# -rw-r--r-- 1 root root   553 Jun  1 08:11 56_2.png
# -rw-r--r-- 1 root root   671 Jun  1 08:11 56_3.png
# -rw-r--r-- 1 root root   774 Jun  1 08:11 56_4.png
# -rw-r--r-- 1 root root   888 Jun  1 08:11 56_5.png
# -rw-r--r-- 1 root root   996 Jun  1 08:11 56_6.png
# -rw-r--r-- 1 root root  1088 Jun  1 08:11 56_7.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 57_0.png
# -rw-r--r-- 1 root root   435 Jun  1 08:11 57_1.png
# -rw-r--r-- 1 root root   532 Jun  1 08:11 57_2.png
# -rw-r--r-- 1 root root   629 Jun  1 08:11 57_3.png
# -rw-r--r-- 1 root root   725 Jun  1 08:11 57_4.png
# -rw-r--r-- 1 root root   823 Jun  1 08:11 57_5.png
# -rw-r--r-- 1 root root   924 Jun  1 08:11 57_6.png
# -rw-r--r-- 1 root root  1012 Jun  1 08:11 57_7.png
# -rw-r--r-- 1 root root   301 Jun  1 08:11 58_0.png
# -rw-r--r-- 1 root root   318 Jun  1 08:11 58_1.png
# -rw-r--r-- 1 root root   332 Jun  1 08:11 58_2.png
# -rw-r--r-- 1 root root   360 Jun  1 08:11 58_3.png
# -rw-r--r-- 1 root root   387 Jun  1 08:11 58_4.png
# -rw-r--r-- 1 root root   402 Jun  1 08:11 58_5.png
# -rw-r--r-- 1 root root   426 Jun  1 08:11 58_6.png
# -rw-r--r-- 1 root root   453 Jun  1 08:11 58_7.png
# -rw-r--r-- 1 root root   306 Jun  1 08:11 59_0.png
# -rw-r--r-- 1 root root   335 Jun  1 08:11 59_1.png
# -rw-r--r-- 1 root root   367 Jun  1 08:11 59_2.png
# -rw-r--r-- 1 root root   408 Jun  1 08:11 59_3.png
# -rw-r--r-- 1 root root   452 Jun  1 08:11 59_4.png
# -rw-r--r-- 1 root root   491 Jun  1 08:11 59_5.png
# -rw-r--r-- 1 root root   530 Jun  1 08:11 59_6.png
# -rw-r--r-- 1 root root   560 Jun  1 08:11 59_7.png
# -rw-r--r-- 1 root root   323 Jun  1 08:11 60_0.png
# -rw-r--r-- 1 root root   387 Jun  1 08:11 60_1.png
# -rw-r--r-- 1 root root   447 Jun  1 08:11 60_2.png
# -rw-r--r-- 1 root root   499 Jun  1 08:11 60_3.png
# -rw-r--r-- 1 root root   578 Jun  1 08:11 60_4.png
# -rw-r--r-- 1 root root   648 Jun  1 08:11 60_5.png
# -rw-r--r-- 1 root root   717 Jun  1 08:11 60_6.png
# -rw-r--r-- 1 root root   770 Jun  1 08:11 60_7.png
# -rw-r--r-- 1 root root   297 Jun  1 08:11 61_0.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 61_1.png
# -rw-r--r-- 1 root root   310 Jun  1 08:11 61_2.png
# -rw-r--r-- 1 root root   315 Jun  1 08:11 61_3.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 61_4.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 61_5.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 61_6.png
# -rw-r--r-- 1 root root   345 Jun  1 08:11 61_7.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 62_0.png
# -rw-r--r-- 1 root root   384 Jun  1 08:11 62_1.png
# -rw-r--r-- 1 root root   444 Jun  1 08:11 62_2.png
# -rw-r--r-- 1 root root   496 Jun  1 08:11 62_3.png
# -rw-r--r-- 1 root root   580 Jun  1 08:11 62_4.png
# -rw-r--r-- 1 root root   641 Jun  1 08:11 62_5.png
# -rw-r--r-- 1 root root   702 Jun  1 08:11 62_6.png
# -rw-r--r-- 1 root root   761 Jun  1 08:11 62_7.png
# -rw-r--r-- 1 root root   329 Jun  1 08:11 63_0.png
# -rw-r--r-- 1 root root   410 Jun  1 08:11 63_1.png
# -rw-r--r-- 1 root root   488 Jun  1 08:11 63_2.png
# -rw-r--r-- 1 root root   573 Jun  1 08:11 63_3.png
# -rw-r--r-- 1 root root   641 Jun  1 08:11 63_4.png
# -rw-r--r-- 1 root root   729 Jun  1 08:11 63_5.png
# -rw-r--r-- 1 root root   826 Jun  1 08:11 63_6.png
# -rw-r--r-- 1 root root   893 Jun  1 08:11 63_7.png
# -rw-r--r-- 1 root root   384 Jun  1 08:11 64_0.png
# -rw-r--r-- 1 root root   588 Jun  1 08:11 64_1.png
# -rw-r--r-- 1 root root   805 Jun  1 08:11 64_2.png
# -rw-r--r-- 1 root root  1038 Jun  1 08:11 64_3.png
# -rw-r--r-- 1 root root  1211 Jun  1 08:11 64_4.png
# -rw-r--r-- 1 root root  1438 Jun  1 08:11 64_5.png
# -rw-r--r-- 1 root root  1647 Jun  1 08:11 64_6.png
# -rw-r--r-- 1 root root  1829 Jun  1 08:11 64_7.png
# -rw-r--r-- 1 root root   338 Jun  1 08:11 65_0.png
# -rw-r--r-- 1 root root   424 Jun  1 08:11 65_1.png
# -rw-r--r-- 1 root root   525 Jun  1 08:11 65_2.png
# -rw-r--r-- 1 root root   613 Jun  1 08:11 65_3.png
# -rw-r--r-- 1 root root   699 Jun  1 08:11 65_4.png
# -rw-r--r-- 1 root root   788 Jun  1 08:11 65_5.png
# -rw-r--r-- 1 root root   851 Jun  1 08:11 65_6.png
# -rw-r--r-- 1 root root   961 Jun  1 08:11 65_7.png
# -rw-r--r-- 1 root root   325 Jun  1 08:11 66_0.png
# -rw-r--r-- 1 root root   386 Jun  1 08:11 66_1.png
# -rw-r--r-- 1 root root   450 Jun  1 08:11 66_2.png
# -rw-r--r-- 1 root root   498 Jun  1 08:11 66_3.png
# -rw-r--r-- 1 root root   570 Jun  1 08:11 66_4.png
# -rw-r--r-- 1 root root   624 Jun  1 08:11 66_5.png
# -rw-r--r-- 1 root root   691 Jun  1 08:11 66_6.png
# -rw-r--r-- 1 root root   740 Jun  1 08:11 66_7.png
# -rw-r--r-- 1 root root   331 Jun  1 08:11 67_0.png
# -rw-r--r-- 1 root root   415 Jun  1 08:11 67_1.png
# -rw-r--r-- 1 root root   513 Jun  1 08:11 67_2.png
# -rw-r--r-- 1 root root   608 Jun  1 08:11 67_3.png
# -rw-r--r-- 1 root root   699 Jun  1 08:11 67_4.png
# -rw-r--r-- 1 root root   789 Jun  1 08:11 67_5.png
# -rw-r--r-- 1 root root   876 Jun  1 08:11 67_6.png
# -rw-r--r-- 1 root root   958 Jun  1 08:11 67_7.png
# -rw-r--r-- 1 root root   329 Jun  1 08:11 68_0.png
# -rw-r--r-- 1 root root   398 Jun  1 08:11 68_1.png
# -rw-r--r-- 1 root root   457 Jun  1 08:11 68_2.png
# -rw-r--r-- 1 root root   521 Jun  1 08:11 68_3.png
# -rw-r--r-- 1 root root   594 Jun  1 08:11 68_4.png
# -rw-r--r-- 1 root root   649 Jun  1 08:11 68_5.png
# -rw-r--r-- 1 root root   702 Jun  1 08:11 68_6.png
# -rw-r--r-- 1 root root   773 Jun  1 08:11 68_7.png
# -rw-r--r-- 1 root root   310 Jun  1 08:11 69_0.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 69_1.png
# -rw-r--r-- 1 root root   325 Jun  1 08:11 69_2.png
# -rw-r--r-- 1 root root   327 Jun  1 08:11 69_3.png
# -rw-r--r-- 1 root root   331 Jun  1 08:11 69_4.png
# -rw-r--r-- 1 root root   341 Jun  1 08:11 69_5.png
# -rw-r--r-- 1 root root   346 Jun  1 08:11 69_6.png
# -rw-r--r-- 1 root root   357 Jun  1 08:11 69_7.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 70_0.png
# -rw-r--r-- 1 root root   311 Jun  1 08:11 70_1.png
# -rw-r--r-- 1 root root   310 Jun  1 08:11 70_2.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 70_3.png
# -rw-r--r-- 1 root root   329 Jun  1 08:11 70_4.png
# -rw-r--r-- 1 root root   328 Jun  1 08:11 70_5.png
# -rw-r--r-- 1 root root   337 Jun  1 08:11 70_6.png
# -rw-r--r-- 1 root root   335 Jun  1 08:11 70_7.png
# -rw-r--r-- 1 root root   345 Jun  1 08:11 71_0.png
# -rw-r--r-- 1 root root   448 Jun  1 08:11 71_1.png
# -rw-r--r-- 1 root root   556 Jun  1 08:11 71_2.png
# -rw-r--r-- 1 root root   678 Jun  1 08:11 71_3.png
# -rw-r--r-- 1 root root   767 Jun  1 08:11 71_4.png
# -rw-r--r-- 1 root root   872 Jun  1 08:11 71_5.png
# -rw-r--r-- 1 root root   954 Jun  1 08:11 71_6.png
# -rw-r--r-- 1 root root  1067 Jun  1 08:11 71_7.png
# -rw-r--r-- 1 root root   306 Jun  1 08:11 72_0.png
# -rw-r--r-- 1 root root   310 Jun  1 08:11 72_1.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 72_2.png
# -rw-r--r-- 1 root root   320 Jun  1 08:11 72_3.png
# -rw-r--r-- 1 root root   338 Jun  1 08:11 72_4.png
# -rw-r--r-- 1 root root   348 Jun  1 08:11 72_5.png
# -rw-r--r-- 1 root root   355 Jun  1 08:11 72_6.png
# -rw-r--r-- 1 root root   360 Jun  1 08:11 72_7.png
# -rw-r--r-- 1 root root   288 Jun  1 08:11 73_0.png
# -rw-r--r-- 1 root root   290 Jun  1 08:11 73_1.png
# -rw-r--r-- 1 root root   293 Jun  1 08:11 73_2.png
# -rw-r--r-- 1 root root   295 Jun  1 08:11 73_3.png
# -rw-r--r-- 1 root root   302 Jun  1 08:11 73_4.png
# -rw-r--r-- 1 root root   304 Jun  1 08:11 73_5.png
# -rw-r--r-- 1 root root   306 Jun  1 08:11 73_6.png
# -rw-r--r-- 1 root root   310 Jun  1 08:11 73_7.png
# -rw-r--r-- 1 root root   301 Jun  1 08:11 74_0.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 74_1.png
# -rw-r--r-- 1 root root   344 Jun  1 08:11 74_2.png
# -rw-r--r-- 1 root root   370 Jun  1 08:11 74_3.png
# -rw-r--r-- 1 root root   392 Jun  1 08:11 74_4.png
# -rw-r--r-- 1 root root   418 Jun  1 08:11 74_5.png
# -rw-r--r-- 1 root root   445 Jun  1 08:11 74_6.png
# -rw-r--r-- 1 root root   481 Jun  1 08:11 74_7.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 75_0.png
# -rw-r--r-- 1 root root   393 Jun  1 08:11 75_1.png
# -rw-r--r-- 1 root root   454 Jun  1 08:11 75_2.png
# -rw-r--r-- 1 root root   524 Jun  1 08:11 75_3.png
# -rw-r--r-- 1 root root   596 Jun  1 08:11 75_4.png
# -rw-r--r-- 1 root root   647 Jun  1 08:11 75_5.png
# -rw-r--r-- 1 root root   698 Jun  1 08:11 75_6.png
# -rw-r--r-- 1 root root   760 Jun  1 08:11 75_7.png
# -rw-r--r-- 1 root root   298 Jun  1 08:11 76_0.png
# -rw-r--r-- 1 root root   302 Jun  1 08:11 76_1.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 76_2.png
# -rw-r--r-- 1 root root   309 Jun  1 08:11 76_3.png
# -rw-r--r-- 1 root root   318 Jun  1 08:11 76_4.png
# -rw-r--r-- 1 root root   316 Jun  1 08:11 76_5.png
# -rw-r--r-- 1 root root   322 Jun  1 08:11 76_6.png
# -rw-r--r-- 1 root root   336 Jun  1 08:11 76_7.png
# -rw-r--r-- 1 root root   373 Jun  1 08:11 77_0.png
# -rw-r--r-- 1 root root   518 Jun  1 08:11 77_1.png
# -rw-r--r-- 1 root root   674 Jun  1 08:11 77_2.png
# -rw-r--r-- 1 root root   820 Jun  1 08:11 77_3.png
# -rw-r--r-- 1 root root   961 Jun  1 08:11 77_4.png
# -rw-r--r-- 1 root root  1098 Jun  1 08:11 77_5.png
# -rw-r--r-- 1 root root  1272 Jun  1 08:11 77_6.png
# -rw-r--r-- 1 root root  1416 Jun  1 08:11 77_7.png
# -rw-r--r-- 1 root root   329 Jun  1 08:11 78_0.png
# -rw-r--r-- 1 root root   397 Jun  1 08:11 78_1.png
# -rw-r--r-- 1 root root   449 Jun  1 08:11 78_2.png
# -rw-r--r-- 1 root root   512 Jun  1 08:11 78_3.png
# -rw-r--r-- 1 root root   559 Jun  1 08:11 78_4.png
# -rw-r--r-- 1 root root   600 Jun  1 08:11 78_5.png
# -rw-r--r-- 1 root root   646 Jun  1 08:11 78_6.png
# -rw-r--r-- 1 root root   691 Jun  1 08:11 78_7.png
# -rw-r--r-- 1 root root   353 Jun  1 08:11 79_0.png
# -rw-r--r-- 1 root root   457 Jun  1 08:11 79_1.png
# -rw-r--r-- 1 root root   586 Jun  1 08:11 79_2.png
# -rw-r--r-- 1 root root   717 Jun  1 08:11 79_3.png
# -rw-r--r-- 1 root root   836 Jun  1 08:11 79_4.png
# -rw-r--r-- 1 root root   950 Jun  1 08:11 79_5.png
# -rw-r--r-- 1 root root  1057 Jun  1 08:11 79_6.png
# -rw-r--r-- 1 root root  1167 Jun  1 08:11 79_7.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 80_0.png
# -rw-r--r-- 1 root root   349 Jun  1 08:11 80_1.png
# -rw-r--r-- 1 root root   382 Jun  1 08:11 80_2.png
# -rw-r--r-- 1 root root   421 Jun  1 08:11 80_3.png
# -rw-r--r-- 1 root root   458 Jun  1 08:11 80_4.png
# -rw-r--r-- 1 root root   484 Jun  1 08:11 80_5.png
# -rw-r--r-- 1 root root   528 Jun  1 08:11 80_6.png
# -rw-r--r-- 1 root root   556 Jun  1 08:11 80_7.png
# -rw-r--r-- 1 root root   360 Jun  1 08:11 81_0.png
# -rw-r--r-- 1 root root   484 Jun  1 08:11 81_1.png
# -rw-r--r-- 1 root root   614 Jun  1 08:11 81_2.png
# -rw-r--r-- 1 root root   756 Jun  1 08:11 81_3.png
# -rw-r--r-- 1 root root   899 Jun  1 08:11 81_4.png
# -rw-r--r-- 1 root root  1011 Jun  1 08:11 81_5.png
# -rw-r--r-- 1 root root  1123 Jun  1 08:11 81_6.png
# -rw-r--r-- 1 root root  1271 Jun  1 08:11 81_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 82_0.png
# -rw-r--r-- 1 root root   391 Jun  1 08:11 82_1.png
# -rw-r--r-- 1 root root   450 Jun  1 08:11 82_2.png
# -rw-r--r-- 1 root root   508 Jun  1 08:11 82_3.png
# -rw-r--r-- 1 root root   560 Jun  1 08:11 82_4.png
# -rw-r--r-- 1 root root   657 Jun  1 08:11 82_5.png
# -rw-r--r-- 1 root root   698 Jun  1 08:11 82_6.png
# -rw-r--r-- 1 root root   739 Jun  1 08:11 82_7.png
# -rw-r--r-- 1 root root   336 Jun  1 08:11 83_0.png
# -rw-r--r-- 1 root root   426 Jun  1 08:11 83_1.png
# -rw-r--r-- 1 root root   505 Jun  1 08:11 83_2.png
# -rw-r--r-- 1 root root   607 Jun  1 08:11 83_3.png
# -rw-r--r-- 1 root root   688 Jun  1 08:11 83_4.png
# -rw-r--r-- 1 root root   795 Jun  1 08:11 83_5.png
# -rw-r--r-- 1 root root   872 Jun  1 08:11 83_6.png
# -rw-r--r-- 1 root root   963 Jun  1 08:11 83_7.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 84_0.png
# -rw-r--r-- 1 root root   312 Jun  1 08:11 84_1.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 84_2.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 84_3.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 84_4.png
# -rw-r--r-- 1 root root   331 Jun  1 08:11 84_5.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 84_6.png
# -rw-r--r-- 1 root root   345 Jun  1 08:11 84_7.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 85_0.png
# -rw-r--r-- 1 root root   369 Jun  1 08:11 85_1.png
# -rw-r--r-- 1 root root   420 Jun  1 08:11 85_2.png
# -rw-r--r-- 1 root root   475 Jun  1 08:11 85_3.png
# -rw-r--r-- 1 root root   519 Jun  1 08:11 85_4.png
# -rw-r--r-- 1 root root   571 Jun  1 08:11 85_5.png
# -rw-r--r-- 1 root root   629 Jun  1 08:11 85_6.png
# -rw-r--r-- 1 root root   676 Jun  1 08:11 85_7.png
# -rw-r--r-- 1 root root   344 Jun  1 08:11 86_0.png
# -rw-r--r-- 1 root root   434 Jun  1 08:11 86_1.png
# -rw-r--r-- 1 root root   529 Jun  1 08:11 86_2.png
# -rw-r--r-- 1 root root   613 Jun  1 08:11 86_3.png
# -rw-r--r-- 1 root root   708 Jun  1 08:11 86_4.png
# -rw-r--r-- 1 root root   784 Jun  1 08:11 86_5.png
# -rw-r--r-- 1 root root   880 Jun  1 08:11 86_6.png
# -rw-r--r-- 1 root root   958 Jun  1 08:11 86_7.png
# -rw-r--r-- 1 root root   376 Jun  1 08:11 87_0.png
# -rw-r--r-- 1 root root   521 Jun  1 08:11 87_1.png
# -rw-r--r-- 1 root root   693 Jun  1 08:11 87_2.png
# -rw-r--r-- 1 root root   833 Jun  1 08:11 87_3.png
# -rw-r--r-- 1 root root   989 Jun  1 08:11 87_4.png
# -rw-r--r-- 1 root root  1122 Jun  1 08:11 87_5.png
# -rw-r--r-- 1 root root  1289 Jun  1 08:11 87_6.png
# -rw-r--r-- 1 root root  1451 Jun  1 08:11 87_7.png
# -rw-r--r-- 1 root root   338 Jun  1 08:11 88_0.png
# -rw-r--r-- 1 root root   443 Jun  1 08:11 88_1.png
# -rw-r--r-- 1 root root   540 Jun  1 08:11 88_2.png
# -rw-r--r-- 1 root root   638 Jun  1 08:11 88_3.png
# -rw-r--r-- 1 root root   742 Jun  1 08:11 88_4.png
# -rw-r--r-- 1 root root   844 Jun  1 08:11 88_5.png
# -rw-r--r-- 1 root root   933 Jun  1 08:11 88_6.png
# -rw-r--r-- 1 root root  1013 Jun  1 08:11 88_7.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 89_0.png
# -rw-r--r-- 1 root root   387 Jun  1 08:11 89_1.png
# -rw-r--r-- 1 root root   447 Jun  1 08:11 89_2.png
# -rw-r--r-- 1 root root   502 Jun  1 08:11 89_3.png
# -rw-r--r-- 1 root root   569 Jun  1 08:11 89_4.png
# -rw-r--r-- 1 root root   620 Jun  1 08:11 89_5.png
# -rw-r--r-- 1 root root   679 Jun  1 08:11 89_6.png
# -rw-r--r-- 1 root root   743 Jun  1 08:11 89_7.png
# -rw-r--r-- 1 root root   334 Jun  1 08:11 90_0.png
# -rw-r--r-- 1 root root   387 Jun  1 08:11 90_1.png
# -rw-r--r-- 1 root root   436 Jun  1 08:11 90_2.png
# -rw-r--r-- 1 root root   500 Jun  1 08:11 90_3.png
# -rw-r--r-- 1 root root   549 Jun  1 08:11 90_4.png
# -rw-r--r-- 1 root root   595 Jun  1 08:11 90_5.png
# -rw-r--r-- 1 root root   644 Jun  1 08:11 90_6.png
# -rw-r--r-- 1 root root   697 Jun  1 08:11 90_7.png
# -rw-r--r-- 1 root root   292 Jun  1 08:11 91_0.png
# -rw-r--r-- 1 root root   301 Jun  1 08:11 91_1.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 91_2.png
# -rw-r--r-- 1 root root   312 Jun  1 08:11 91_3.png
# -rw-r--r-- 1 root root   316 Jun  1 08:11 91_4.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 91_5.png
# -rw-r--r-- 1 root root   327 Jun  1 08:11 91_6.png
# -rw-r--r-- 1 root root   331 Jun  1 08:11 91_7.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 92_0.png
# -rw-r--r-- 1 root root   375 Jun  1 08:11 92_1.png
# -rw-r--r-- 1 root root   438 Jun  1 08:11 92_2.png
# -rw-r--r-- 1 root root   509 Jun  1 08:11 92_3.png
# -rw-r--r-- 1 root root   567 Jun  1 08:11 92_4.png
# -rw-r--r-- 1 root root   612 Jun  1 08:11 92_5.png
# -rw-r--r-- 1 root root   653 Jun  1 08:11 92_6.png
# -rw-r--r-- 1 root root   741 Jun  1 08:11 92_7.png
# -rw-r--r-- 1 root root   292 Jun  1 08:11 93_0.png
# -rw-r--r-- 1 root root   308 Jun  1 08:11 93_1.png
# -rw-r--r-- 1 root root   308 Jun  1 08:11 93_2.png
# -rw-r--r-- 1 root root   315 Jun  1 08:11 93_3.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 93_4.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 93_5.png
# -rw-r--r-- 1 root root   324 Jun  1 08:11 93_6.png
# -rw-r--r-- 1 root root   330 Jun  1 08:11 93_7.png
# -rw-r--r-- 1 root root   307 Jun  1 08:11 94_0.png
# -rw-r--r-- 1 root root   345 Jun  1 08:11 94_1.png
# -rw-r--r-- 1 root root   390 Jun  1 08:11 94_2.png
# -rw-r--r-- 1 root root   429 Jun  1 08:11 94_3.png
# -rw-r--r-- 1 root root   493 Jun  1 08:11 94_4.png
# -rw-r--r-- 1 root root   510 Jun  1 08:11 94_5.png
# -rw-r--r-- 1 root root   574 Jun  1 08:11 94_6.png
# -rw-r--r-- 1 root root   594 Jun  1 08:11 94_7.png
# -rw-r--r-- 1 root root   288 Jun  1 08:11 95_0.png
# -rw-r--r-- 1 root root   295 Jun  1 08:11 95_1.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 95_2.png
# -rw-r--r-- 1 root root   305 Jun  1 08:11 95_3.png
# -rw-r--r-- 1 root root   309 Jun  1 08:11 95_4.png
# -rw-r--r-- 1 root root   314 Jun  1 08:11 95_5.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 95_6.png
# -rw-r--r-- 1 root root   321 Jun  1 08:11 95_7.png
# -rw-r--r-- 1 root root   300 Jun  1 08:11 96_0.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 96_1.png
# -rw-r--r-- 1 root root   340 Jun  1 08:11 96_2.png
# -rw-r--r-- 1 root root   368 Jun  1 08:11 96_3.png
# -rw-r--r-- 1 root root   388 Jun  1 08:11 96_4.png
# -rw-r--r-- 1 root root   418 Jun  1 08:11 96_5.png
# -rw-r--r-- 1 root root   444 Jun  1 08:11 96_6.png
# -rw-r--r-- 1 root root   470 Jun  1 08:11 96_7.png
# -rw-r--r-- 1 root root   317 Jun  1 08:11 97_0.png
# -rw-r--r-- 1 root root   374 Jun  1 08:11 97_1.png
# -rw-r--r-- 1 root root   448 Jun  1 08:11 97_2.png
# -rw-r--r-- 1 root root   490 Jun  1 08:11 97_3.png
# -rw-r--r-- 1 root root   562 Jun  1 08:11 97_4.png
# -rw-r--r-- 1 root root   637 Jun  1 08:11 97_5.png
# -rw-r--r-- 1 root root   697 Jun  1 08:11 97_6.png
# -rw-r--r-- 1 root root   752 Jun  1 08:11 97_7.png
# -rw-r--r-- 1 root root   319 Jun  1 08:11 98_0.png
# -rw-r--r-- 1 root root   377 Jun  1 08:11 98_1.png
# -rw-r--r-- 1 root root   454 Jun  1 08:11 98_2.png
# -rw-r--r-- 1 root root   509 Jun  1 08:11 98_3.png
# -rw-r--r-- 1 root root   568 Jun  1 08:11 98_4.png
# -rw-r--r-- 1 root root   635 Jun  1 08:11 98_5.png
# -rw-r--r-- 1 root root   700 Jun  1 08:11 98_6.png
# -rw-r--r-- 1 root root   754 Jun  1 08:11 98_7.png
# -rw-r--r-- 1 root root   313 Jun  1 08:11 99_0.png
# -rw-r--r-- 1 root root   367 Jun  1 08:11 99_1.png
# -rw-r--r-- 1 root root   423 Jun  1 08:11 99_2.png
# -rw-r--r-- 1 root root   464 Jun  1 08:11 99_3.png
# -rw-r--r-- 1 root root   521 Jun  1 08:11 99_4.png
# -rw-r--r-- 1 root root   576 Jun  1 08:11 99_5.png
# -rw-r--r-- 1 root root   629 Jun  1 08:11 99_6.png
# -rw-r--r-- 1 root root   692 Jun  1 08:11 99_7.png
# -rw-r--r-- 1 root root   940 Jun  1 08:11 make_labels.py

# %%
# change makefile to have GPU,OPENCV, CUDNN enabled
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# Compile Source
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1150:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1420:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1424:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1428:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1431:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:511:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:875:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:894:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:930:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2044:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2043:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1061:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:230:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:264:18: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum cudaError_enum’ [-Wenum-compare]
#        if (status != CUDA_SUCCESS)
#                   ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:395:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:395:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:395:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:405:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:426:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:441:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:447:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# At top level:
# ./src/dark_cuda.c:287:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#  static cublasHandle_t switchBlasHandle[16];
#                        ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:286:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#  static int switchBlasInit[16] = { 0 };
#             ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1342:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#          int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#              ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1777:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1909:9: warning: unused variable ‘i’ [-Wunused-variable]
#      int i;
#          ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:438:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:395:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#              (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:495:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:588:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:709:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:707:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1326:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#                  double cur_prob = 0;
#                         ^~~~~~~~
# ./src/detector.c:1347:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1346:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1890:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:101:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:115:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:426:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:707:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#      float avg_anyobj = 0;
#            ^~~~~~~~~~
# ./src/yolo_layer.c:706:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#      float avg_obj = 0;
#            ^~~~~~~
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#      float avg_cat = 0;
#            ^~~~~~~
# ...
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:120:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:379:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-06-01 08:12:21--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  60.8MB/s    in 4.2s
#
# 2022-06-01 08:12:25 (56.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # 2. Tracking

# %%
import cv2
import IPython
import numpy as np
import time
import math
from google.colab.patches import cv2_imshow

# %%
min_confidence = 0.5
weight_file = 'yolov3.weights'
cfg_file = 'cfg/yolov3.cfg'
name_file = 'data/coco.names'
file_name = 'cabc30fc-e7726578.mp4'

# %%
# Load Yolo
net = cv2.dnn.readNet(weight_file, cfg_file)

# %%
classes = [] 
with open(name_file, 'r') as f:
  classes = [line.strip() for line in f.readlines()]
print(classes)
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0]-1] for i in net.getUnconnectedOutLayers()]

# %%
# cabc30fc-e7726578.mp4
from google.colab import files 
files.upload()
# Out:
#      <input type="file" id="files-3de8c9fe-35b5-498e-9471-3f0951e66b86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3de8c9fe-35b5-498e-9471-3f0951e66b86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cabc30fc-e7726578.mp4 to cabc30fc-e7726578.mp4

# %%
def writeFrame(img):
    # use global variable, writer
    global writer
    height, width = img.shape[:2]
    if writer is None and output_name is not None:
        fourcc = cv2.VideoWriter_fourcc(*'MJPG')
        writer = cv2.VideoWriter(output_name, fourcc, 24, (width, height), True)
    if writer is not None:
        writer.write(img)

# %%
frame_count = 0
# initialize the video writer 
writer = None
output_name = 'output_tracking.avi'

detected = False
frame_mode = 'Tracking'
elapsed_time = 0
tracker = cv2.TrackerKCF_create()
trackers = cv2.MultiTracker_create()

vs = cv2.VideoCapture(file_name)

while True:
    start_time = time.time()
    frame_count += 1
    ret, frame = vs.read()
    if frame is None:
        print('### No more frame ###')
        break
    IPython.display.clear_output(wait=True)

    if detected:
        frame_mode = 'Tracking'
        (success, boxes) = trackers.update(frame)
        for box in boxes:
           (x, y, w, h) = [int(v) for v in box]
           cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    else:
        frame_mode = 'Detection'
        height, width, channedls = frame.shape
        # Detecting objects
        # https://docs.opencv.org/master/d6/d0f/group__dnn.html
        blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

        net.setInput(blob)
        outs = net.forward(output_layers)

        class_ids = []
        confidences = []
        boxes = []

        for out in outs:
            for detection in out:
                scores = detection[5:]
                class_id = np.argmax(scores)
                confidence = scores[class_id]
                if (confidence > min_confidence) and (class_id == 2):
                    # Object detected
                    center_x = int(detection[0] * width)
                    center_y = int(detection[1] * height)
                    w = int(detection[2] * width)
                    h = int(detection[3] * height)

                    # Rectangle coordinates
                    x = int(center_x - w / 2)
                    y = int(center_y - h / 2)

                    boxes.append([x, y, w, h])
                    confidences.append(float(confidence))
                    class_ids.append(class_id)
        # Region of Interest
        roi_left = int(0.3 * width)
        roi_right = int(0.6 * width)

        indexes = cv2.dnn.NMSBoxes(boxes, confidences, min_confidence, 0.4)
        font = cv2.FONT_HERSHEY_COMPLEX
        for i in range(len(boxes)):
            if i in indexes:
                x, y, w, h = boxes[i]
                # Eliminate Small object(<50)
                if (w > 50) and (x > roi_left) and (x < roi_right):
                    selected = boxes[i]
                    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 255), 5)    
        trackers.add(tracker, frame, tuple(selected))
        detected = True 

    cv2_imshow(frame)
    writeFrame(frame)
    frame_time = time.time() - start_time
    elapsed_time += frame_time
    print("[{}] Frame {} time {}".format(frame_mode, frame_count, frame_time))

print("Elapsed time {}".format(elapsed_time))
vs.release()
