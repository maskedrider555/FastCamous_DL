# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls -al '/gdrive/MyDrive/Darknet/custom'
# Out:
# ls: cannot access '/gdrive/MyDrive/Darknet/custom': No such file or directory

# %% [markdown]
# # 2. Custom

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-05-10 10:06:41--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  56.4MB/s    in 2.7s
#
# 2022-05-10 10:06:44 (56.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls -al
# Out:
# total 158700
# drwxr-xr-x 1 root root      4096 May 10 10:10 .
# drwxr-xr-x 1 root root      4096 May 10 10:05 ..
# drwxr-xr-x 4 root root      4096 May  3 13:41 .config
# drwx------ 2 root root      4096 May 10 10:10 Custom
# -rw-r--r-- 1 root root 162482580 Mar 25  2018 darknet53.conv.74
# drwxr-xr-x 1 root root      4096 May  3 13:42 sample_data

# %%
# !cp -r '/gdrive/MyDrive/Darknet/Custom' .

# %%
# !mkdir bakcup

# %%
# !ls -al '/gdrive/MyDrive/Darknet/Custom'
# Out:
# total 407167
# drwx------ 2 root root      4096 May  8 02:34  cfg
# -rw------- 1 root root   3213624 May 10 10:20  darknet
# -rw------- 1 root root   3213624 Jun 18  2021 'darknet (1)'
# -rw------- 1 root root 162482580 May  8 02:33  darknet53.conv.74
# drwx------ 3 root root      4096 May  8 02:34  data
# drwx------ 2 root root      4096 May  8 02:34  Fruit
# -rw------- 1 root root      8342 Jun 18  2021  yolov3.cfg
# -rw------- 1 root root 248007048 May  8 00:32  yolov3.weights

# %%
# !chmod +x ./Custom/darknet

# %%
# Train the Model
# !./Custom/darknet detector train Custom/Fruit/custom_data.data Custom/cfg/custom-train-yolo.cfg darknet53.conv.74 -dont_show
# Out:
# custom-train-yolo
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# Map
# !./Custom/darknet detector map Custom/Fruit/custom_data.data Custom/cfg/custom-train-yolo.cfg backup/custom-train-yolo_last.weights

# %%
# Test
# Map
# !./Custom/darknet detector test Custom/Fruit/custom_data.data Custom/cfg/custom-train-yolo.cfg backup/custom-train-yolo_last.weights fruit10.jpg

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('predictions.jpg')
cv2_imshow(img)
